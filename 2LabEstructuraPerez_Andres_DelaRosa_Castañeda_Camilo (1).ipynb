# %% [markdown]
# **Imports necesarios:**

# %%
import pandas as pd
import networkx as nx
from math import radians, sin, cos, sqrt, atan2
import matplotlib.pyplot as plt
import folium
from IPython.display import display
from geopy.distance import great_circle
from IPython.display import IFrame
from IPython.display import HTML

# %% [markdown]
# **Metodos:**

# %%
# Función para calcular la distancia entre dos coordenadas geográficas
def haversine(lat1, lon1, lat2, lon2):
    radius = 6371  # Radio de la Tierra en kilómetros
    lat1, lon1, lat2, lon2 = map(radians, [lat1, lon1, lat2, lon2])
    dlat = lat2 - lat1
    dlon = lon2 - lon1
    a = sin(dlat / 2)**2 + cos(lat1) * cos(lat2) * sin(dlon / 2)**2
    c = 2 * atan2(sqrt(a), sqrt(1 - a))
    distance = radius * c
    return distance


def mostrar_informacion_aeropuerto(codigo_aeropuerto):
    if codigo_aeropuerto in G.nodes:
        aeropuerto_info = {
            "Código": codigo_aeropuerto,
            "Nombre": data[data["Source Airport Code"] == codigo_aeropuerto]["Source Airport Name"].values[0],
            "Ciudad": data[data["Source Airport Code"] == codigo_aeropuerto]["Source Airport City"].values[0],
            "País": data[data["Source Airport Code"] == codigo_aeropuerto]["Source Airport Country"].values[0],
            "Latitud": data[data["Source Airport Code"] == codigo_aeropuerto]["Source Airport Latitude"].values[0],
            "Longitud": data[data["Source Airport Code"] == codigo_aeropuerto]["Source Airport Longitude"].values[0]
        }

        print("Información del aeropuerto:")
        for key, value in aeropuerto_info.items():
            print(f"{key}: {value}")
    else:
        print(f"No se encontró información para el aeropuerto con código {codigo_aeropuerto}")

def obtener_informacion_aeropuerto(codigo_aeropuerto):
    if codigo_aeropuerto in G.nodes:
        aeropuerto_info = {
            "Código": codigo_aeropuerto,
            "Nombre": data[data["Source Airport Code"] == codigo_aeropuerto]["Source Airport Name"].values[0],
            "Ciudad": data[data["Source Airport Code"] == codigo_aeropuerto]["Source Airport City"].values[0],
            "País": data[data["Source Airport Code"] == codigo_aeropuerto]["Source Airport Country"].values[0],
            "Latitud": data[data["Source Airport Code"] == codigo_aeropuerto]["Source Airport Latitude"].values[0],
            "Longitud": data[data["Source Airport Code"] == codigo_aeropuerto]["Source Airport Longitude"].values[0]
        }
        return aeropuerto_info
    else:
        return None

# %% [markdown]
# **Creamos el grafo:**

# %%
data = pd.read_csv("flights_final.csv")
# Crear un grafo no dirigido y Crear diccionarios para almacenar las posiciones de origen y destino
G = nx.Graph()
pos_aeropuerto = {}


for index, row in data.iterrows():
    source_airport = row["Source Airport Code"]
    airport_name = row["Source Airport Name"]
    airport_city = row["Source Airport City"]
    airport_country = row["Source Airport Country"]
    airport_lat = row["Source Airport Latitude"]
    airport_lon = row["Source Airport Longitude"]
    destination_airport = row["Destination Airport Code"]
    source_coords = (row["Source Airport Latitude"], row["Source Airport Longitude"])
    dest_coords = (row["Destination Airport Latitude"], row["Destination Airport Longitude"])

    # Agregar nodos (aeropuertos)
    if not G.has_node(source_airport):
        G.add_node(source_airport, pos=source_coords)
        pos_aeropuerto[source_airport] = source_coords
    if not G.has_node(destination_airport):
        G.add_node(destination_airport, pos=dest_coords)
        pos_aeropuerto[destination_airport] = dest_coords

    # Calcular la distancia y agregar la arista ponderada
    distance = haversine(*source_coords, *dest_coords)
    G.add_edge(source_airport, destination_airport, weight=distance)

orden = G.number_of_nodes()
print(f"El orden del grafo es {orden}")
# Out:
# El orden del grafo es 3256

# %% [markdown]
# **Mapa de los Aeropuertos**

# %%
# Crear un mapa centrado en una ubicación de referencia (por ejemplo, la latitud y longitud de un aeropuerto)
map_center = (data["Source Airport Latitude"].mean(), data["Source Airport Longitude"].mean())
m = folium.Map(location=map_center, zoom_start=3)
numero_de_marcadores = 0

# Agregar marcadores para los aeropuertos de origen
for airport, pos in pos_aeropuerto.items():
    folium.Marker(location=pos, tooltip=airport).add_to(m)
    numero_de_marcadores += 1

# Mostrar el mapa
display(m)
print("Numero de marcadores: ",numero_de_marcadores)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1ed97a1f24c71e608aa784849aa2d8a9 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1ed97a1f24c71e608aa784849aa2d8a9&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1ed97a1f24c71e608aa784849aa2d8a9 = L.map(
#                 &quot;map_1ed97a1f24c71e608aa784849aa2d8a9&quot;,
#                 {
#                     center: [31.652160622905978, 11.346333260542552],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 3,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5be65f7e1d5ef39e83cf1be7b3eb6d06 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_1ed97a1f24c71e608aa784849aa2d8a9);
#
#
#             var marker_729ce9b89389aec8ebb8e44dde5f36b6 = L.marker(
#                 [10.152, 76.401901],
#                 {}
#             ).addTo(map_1ed97a1f24c71e608aa784849aa2d8a9);
#
#
#             marker_729ce9b89389aec8ebb8e44dde5f36b6.bindTooltip(
#                 `&lt;div&gt;
#                      COK
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_72e8e1ca67aace366a4ae7e1c15f2caa = L.marker(
#                 [25.32859993, 55.51720047],
#                 {}
#             ).addTo(map_1ed97a1f24c71e608aa784849aa2d8a9);
#
#
#             marker_72e8e1ca67aace366a4ae7e1c15f2caa.bindTooltip(
#                 `&lt;div&gt;
#                      SHJ
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_dadf7b2352bb82edd92d467f789968ff = L.marker(
#                 [-22.80999947, -43.25055695],
#                 {}
#             ).addTo(map_1ed97a1f24c71e608aa784849aa2d8a9);
#
#
#             marker_dadf7b2352bb82edd92d467f789968ff.bindTooltip(
#                 `&lt;div&gt;
#                      GIG
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_9bf9a4f84f23b832f71089e9706d6f8b = L.marker(
#                 [-15.86916733, -47.92083359],
#                 {}
#             ).addTo(map_1ed97a1f24c71e608aa784849aa2d8a9);
#
#
#             marker_9bf9a4f84f23b832f71089e9706d6f8b.bindTooltip(
#                 `&lt;div&gt;
#                      BSB
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_604d13140daf204ea65da9c708f9ff66 = L.marker(
#                 [45.648399, 12.1944],
#                 {}
#             ).addTo(map_1ed97a1f24c71e608aa784849aa2d8a9);
#
#
#             marker_604d13140daf204ea65da9c708f9ff66.bindTooltip(
#                 `&lt;div&gt;
#                      TSF
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_94b706ac3ed34489cb39ba0b4e7ce24f = L.marker(
#                 [41.138901, 16.760599],
#                 {}
#             ).addTo(map_1ed97a1f24c71e608aa784849aa2d8a9);
#
#
#             marker_94b706ac3ed34489cb39ba0b4e7ce24f.bindTooltip(
#                 `&lt;div&gt;
#                      BRI
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_ee9f6334f3f17e16fff9395c69ea341d = L.marker(
#                 [49.012798, 2.55],
#                 {}
#             ).addTo(map_1ed97a1f24c71e608aa784849aa2d8a9);
#
#
#             marker_ee9f6334f3f17e16fff9395c69ea341d.bindTooltip(
#                 `&lt;div&gt;
#                      CDG
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_074364e87b6224ae50deec331e425ee5 = L.marker(
#                 [43.810001, 11.2051],
#                 {}
#             ).addTo(map_1ed97a1f24c71e608aa784849aa2d8a9);
#
#
#             marker_074364e87b6224ae50deec331e425ee5.bindTooltip(
#                 `&lt;div&gt;
#                      FLR
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_e6d44e8460c6bfa81452e10765bcd16f = L.marker(
#                 [-23.62611008, -46.65638733],
#                 {}
#             ).addTo(map_1ed97a1f24c71e608aa784849aa2d8a9);
#
#
#             marker_e6d44e8460c6bfa81452e10765bcd16f.bindTooltip(
#                 `&lt;div&gt;
#                      CGH
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_2fda02c62a98eb417f3dfc786ce8cdb4 = L.marker(
#                 [-15.65289974, -56.11669922],
#                 {}
#             ).addTo(map_1ed97a1f24c71e608aa784849aa2d8a9);
#
#
#             marker_2fda02c62a98eb417f3dfc786
# Numero de marcadores:  3256

# %% [markdown]
# **Menu:**

# %%
aeropuerto_origen_seleccionado = None
while True:
    print("\nMenú de consulta de aeropuertos:")
    print("1. Mostrar información de un aeropuerto y Mostrar la información de los 10 aeropuertos cuyos caminos mínimos desde el vértice dado sean los más largos.")
    print("2. Mostrar el camino mínimo entre el primer y el segundo vértice sobre el mapa de la interfaz gráfica")
    print("3. Salir")
    opcion = input("Seleccione una opción: ")

    if opcion == '1':
        codigo_aeropuerto = input("Ingrese el código del aeropuerto: ")
        aeropuerto_origen_seleccionado = codigo_aeropuerto
        mostrar_informacion_aeropuerto(codigo_aeropuerto)

        longest_paths = nx.single_source_dijkstra_path_length(G, codigo_aeropuerto)
        sorted_longest_paths = sorted(longest_paths.items(), key=lambda x: x[1], reverse=True)[:10]

        print("\nLos 10 aeropuertos con los caminos mínimos más largos:")
        for airport, distance in sorted_longest_paths:
            mostrar_informacion_aeropuerto(airport)
            print(f"Distancia del camino mínimo: {distance} km")
            print("-------------------------------------------")


    elif opcion == '2':
        if aeropuerto_origen_seleccionado is None:
            print("Primero debes seleccionar un aeropuerto de origen en la opción 1.")
        else:
            source_vertex = aeropuerto_origen_seleccionado  # Utiliza el aeropuerto seleccionado en la opción 1 como origen
            dest_vertex = input("Ingresa el código del aeropuerto de destino: ")

            if source_vertex not in G.nodes or dest_vertex not in G.nodes:
                print("Uno o ambos aeropuertos no se encuentran en el grafo.")
            else:
                    try:
                        shortest_path = nx.shortest_path(G, source=source_vertex, target=dest_vertex, weight="weight")
                    except nx.NetworkXNoPath:
                        print("No se encontró un camino entre los aeropuertos seleccionados.")
                        shortest_path = []

                    # Obtener las coordenadas del primer aeropuerto en el camino más corto
                    if shortest_path:
                        center_coords = G.nodes[shortest_path[0]]['pos']
                    else:
                        center_coords = (0.0, 0.0)  # Coordenadas por defecto si no hay aeropuertos en el camino

                    # Crear un mapa con Folium
                    m = folium.Map(location=center_coords, zoom_start=5)

                    # Agregar los aeropuertos al mapa
                    # Agregar los aeropuertos al mapa
                    for airport in shortest_path:
                        lat, lon = G.nodes[airport]['pos']
                        info_aeropuerto = obtener_informacion_aeropuerto(airport)
                        if info_aeropuerto:
                            popup_content = f"<b>{info_aeropuerto['Nombre']}</b><br>Código: {info_aeropuerto['Código']}<br>Ciudad: {info_aeropuerto['Ciudad']}<br>País: {info_aeropuerto['País']}<br>Latitud: {info_aeropuerto['Latitud']}<br>Longitud: {info_aeropuerto['Longitud']}"
                            folium.Marker([lat, lon], popup=popup_content).add_to(m)
                        else:
                            folium.Marker([lat, lon], popup="Aeropuerto sin información").add_to(m)


                    # Agregar las líneas que conectan los aeropuertos en el recorrido
                    for i in range(len(shortest_path) - 1):
                        node1 = shortest_path[i]
                        node2 = shortest_path[i + 1]
                        lat1, lon1 = G.nodes[node1]['pos']
                        lat2, lon2 = G.nodes[node2]['pos']
                        folium.PolyLine([(lat1, lon1), (lat2, lon2)], color="blue").add_to(m)

                    # Mostrar el mapa interactivo
                    display(m)


    elif opcion == "3":

        break
    else:
        print("Opción no válida. Por favor, seleccione 1 o 2 para Mostrar información o Salir.")
# Out:
# Menú de consulta de aeropuertos:
# 1. Mostrar información de un aeropuerto y Mostrar la información de los 10 aeropuertos cuyos caminos mínimos desde el vértice dado sean los más largos.
# 2. Mostrar el camino mínimo entre el primer y el segundo vértice sobre el mapa de la interfaz gráfica
# 3. Salir
# Seleccione una opción: 1
# Ingrese el código del aeropuerto: COK
# Información del aeropuerto:
# Código: COK
# Nombre: Cochin International Airport
# Ciudad: Kochi
# País: India
# Latitud: 10.152
# Longitud: 76.401901
#
# Los 10 aeropuertos con los caminos mínimos más largos:
# Información del aeropuerto:
# Código: IPC
# Nombre: Mataveri Airport
# Ciudad: Easter Island
# País: Chile
# Latitud: -27.16480064
# Longitud: -109.4219971
# Distancia del camino mínimo: 19627.05478139015 km
# -------------------------------------------
# Información del aeropuerto:
# Código: MPN
# Nombre: Mount Pleasant Airport
# Ciudad: Mount Pleasant
# País: Falkland Islands
# Latitud: -51.82279968
# Longitud: -58.44720078
# Distancia del camino mínimo: 19238.09703060891 km
# -------------------------------------------
# Información del aeropuerto:
# Código: TBP
# Nombre: Capitan FAP Pedro Canga Rodriguez Airport
# Ciudad: Tumbes
# País: Peru
# Latitud: -3.55253005
# Longitud: -80.38140106
# Distancia del camino mínimo: 18965.660957928983 km
# -------------------------------------------
# Información del aeropuerto:
# Código: PIU
# Nombre: Capitán FAP Guillermo Concha Iberico International Airport
# Ciudad: Piura
# País: Peru
# Latitud: -5.205749989
# Longitud: -80.61640167
# Distancia del camino mínimo: 18807.594248652284 km
# -------------------------------------------
# Información del aeropuerto:
# Código: USH
# Nombre: Malvinas Argentinas Airport
# Ciudad: Ushuaia
# País: Argentina
# Latitud: -54.8433
# Longitud: -68.2958
# Distancia del camino mínimo: 18781.417660857813 km
# -------------------------------------------
# Información del aeropuerto:
# Código: BBA
# Nombre: Balmaceda Airport
# Ciudad: Balmaceda
# País: Chile
# Latitud: -45.91609955
# Longitud: -71.6894989
# Distancia del camino mínimo: 18717.668371371463 km
# -------------------------------------------
# Información del aeropuerto:
# Código: PUQ
# Nombre: Pdte. Carlos Ibañez del Campo Airport
# Ciudad: Punta Arenas
# País: Chile
# Latitud: -53.002602
# Longitud: -70.854599
# Distancia del camino mínimo: 18676.96706131807 km
# -------------------------------------------
# Información del aeropuerto:
# Código: RGA
# Nombre: Hermes Quijada International Airport
# Ciudad: Rio Grande
# País: Argentina
# Latitud: -53.7777
# Longitud: -67.7494
# Distancia del camino mínimo: 18661.35388150012 km
# -------------------------------------------
# Información del aeropuerto:
# Código: CIX
# Nombre: Capitan FAP Jose A Quinones Gonzales International Airport
# Ciudad: Chiclayo
# País: Peru
# Latitud: -6.787479877
# Longitud: -79.82810211
# Distancia del camino mínimo: 18611.30133002254 km
# -------------------------------------------
# Información del aeropuerto:
# Código: GPS
# Nombre: Seymour Airport
# Ciudad: Galapagos
# País: Ecuador
# Latitud: -0.453758001
# Longitud: -90.26589966
# Distancia del camino mínimo: 18603.69869402214 km
# -------------------------------------------
#
# Menú de consulta de aeropuertos:
# 1. Mostrar información de un aeropuerto y Mostrar la información de los 10 aeropuertos cuyos caminos mínimos desde el vértice dado sean los más largos.
# 2. Mostrar el camino mínimo entre el primer y el segundo vértice sobre el mapa de la interfaz gráfica
# 3. Salir
# Seleccione una opción: 2
# Ingresa el código del aeropuerto de destino: COK
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_178d18e5dcc36b90e708a7f2cc06fe0e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_178d18e5dcc36b90e708a7f2cc06fe0e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_178d18e5dcc36b90e708a7f2cc06fe0e = L.map(
#                 &quot;map_178d18e5dcc36b90e708a7f2cc06fe0e&quot;,
#                 {
#                     center: [10.152, 76.401901],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a3dc2decfe6cc6fb0baa900d220a19fe = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_178d18e5dcc36b90e708a7f2cc06fe0e);
#
#
#             var marker_25905aacbbc9590cac24287ec459529a = L.marker(
#                 [10.152, 76.401901],
#                 {}
#             ).addTo(map_178d18e5dcc36b90e708a7f2cc06fe0e);
#
#
#         var popup_00d69d2ac6ca1d5b560049a56b583659 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_b92147db88ea4bf5ec2755cb95fb319d = $(`&lt;div id=&quot;html_b92147db88ea4bf5ec2755cb95fb319d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Cochin International Airport&lt;/b&gt;&lt;br&gt;Código: COK&lt;br&gt;Ciudad: Kochi&lt;br&gt;País: India&lt;br&gt;Latitud: 10.152&lt;br&gt;Longitud: 76.401901&lt;/div&gt;`)[0];
#                 popup_00d69d2ac6ca1d5b560049a56b583659.setContent(html_b92147db88ea4bf5ec2755cb95fb319d);
#
#
#
#         marker_25905aacbbc9590cac24287ec459529a.bindPopup(popup_00d69d2ac6ca1d5b560049a56b583659)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
# Menú de consulta de aeropuertos:
# 1. Mostrar información de un aeropuerto y Mostrar la información de los 10 aeropuertos cuyos caminos mínimos desde el vértice dado sean los más largos.
# 2. Mostrar el camino mínimo entre el primer y el segundo vértice sobre el mapa de la interfaz gráfica
# 3. Salir
# Seleccione una opción: 2
# Ingresa el código del aeropuerto de destino: BAQ
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_fca4ca4079c4f4f7b1bfeed088a6937c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_fca4ca4079c4f4f7b1bfeed088a6937c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_fca4ca4079c4f4f7b1bfeed088a6937c = L.map(
#                 &quot;map_fca4ca4079c4f4f7b1bfeed088a6937c&quot;,
#                 {
#                     center: [10.152, 76.401901],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_681f5712f561d386a91b20cb3c92bfdd = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_fca4ca4079c4f4f7b1bfeed088a6937c);
#
#
#             var marker_9b8fc2d7a80a55c43c3465d33e2291e3 = L.marker(
#                 [10.152, 76.401901],
#                 {}
#             ).addTo(map_fca4ca4079c4f4f7b1bfeed088a6937c);
#
#
#         var popup_ac45a4ab990379bacdae9dd114e0bac7 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_09cc2d6ee6f714bb54d9a86e10806d52 = $(`&lt;div id=&quot;html_09cc2d6ee6f714bb54d9a86e10806d52&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Cochin International Airport&lt;/b&gt;&lt;br&gt;Código: COK&lt;br&gt;Ciudad: Kochi&lt;br&gt;País: India&lt;br&gt;Latitud: 10.152&lt;br&gt;Longitud: 76.401901&lt;/div&gt;`)[0];
#                 popup_ac45a4ab990379bacdae9dd114e0bac7.setContent(html_09cc2d6ee6f714bb54d9a86e10806d52);
#
#
#
#         marker_9b8fc2d7a80a55c43c3465d33e2291e3.bindPopup(popup_ac45a4ab990379bacdae9dd114e0bac7)
#         ;
#
#
#
#
#             var marker_6889f9f9febb9c6668c9c6101f4ff7ab = L.marker(
#                 [25.25279999, 55.36439896],
#                 {}
#             ).addTo(map_fca4ca4079c4f4f7b1bfeed088a6937c);
#
#
#         var popup_598de1d5dd92a58dae73a578f7aacccc = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_eee1ab78f5a71682ffb53ee09a9c16a9 = $(`&lt;div id=&quot;html_eee1ab78f5a71682ffb53ee09a9c16a9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Dubai International Airport&lt;/b&gt;&lt;br&gt;Código: DXB&lt;br&gt;Ciudad: Dubai&lt;br&gt;País: United Arab Emirates&lt;br&gt;Latitud: 25.25279999&lt;br&gt;Longitud: 55.36439896&lt;/div&gt;`)[0];
#                 popup_598de1d5dd92a58dae73a578f7aacccc.setContent(html_eee1ab78f5a71682ffb53ee09a9c16a9);
#
#
#
#         marker_6889f9f9febb9c6668c9c6101f4ff7ab.bindPopup(popup_598de1d5dd92a58dae73a578f7aacccc)
#         ;
#
#
#
#
#             var marker_aab6156a2f953ca0c2ecc1f0b6cf8aad = L.marker(
#                 [40.471926, -3.56264],
#                 {}
#             ).addTo(map_fca4ca4079c4f4f7b1bfeed088a6937c);
#
#
#         var popup_de330b5bce652a45bd59661fce1e98c2 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_e8cae1dc384706a11193e579cc82f757 = $(`&lt;div id=&quot;html_e8cae1dc384706a11193e579cc82f757&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Adolfo Suárez Madrid–Barajas Airport&lt;/b&gt;&lt;br&gt;Código: MAD&lt;br&gt;Ciudad: Madrid&lt;br&gt;País: Spain&lt;br&gt;Latitud: 40.471926&lt;br&gt;Longitud: -3.56264&lt;/div&gt;`)[0];
#                 popup_de330b5bce652a45bd59661fce1e98c2.setContent(html_e8cae1dc384706a11193e579cc82f757);
#
#
#
#         marker_aab6156a2f953ca0c2ecc1f0b6cf8aad.bindPopup(popup_de330b5bce652a45bd59661fce1e98c2)
#         ;
#
#
#
#
#             var marker_0fddd815e59c602cc1db21c054067870 = L.marker(
#                 [6.16454, -75.4231],
#                 {}
#             ).addTo(map_fca4ca4079c4f4f7b1bfeed088a6937c);
#
#
#         var popup_12f4de33ba3f32c855a8471832cf519d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_c42bdf193dccfb00967d3cc4e2ed5feb = $(`&lt;div id=&quot;html_c42bdf193dccfb00967d3cc4e2ed5feb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Jose Maria Córdova International Airport&lt;/b&gt;&lt;br&gt;Código: MDE&lt;br&gt;Ciudad: Rio Negro&lt;br&gt;País: Colombia&lt;br&gt;Latitud: 6.16454&lt;br&gt;Longitud: -75.4231&lt;/div&gt;`)[0];
#                 popup_12f4de33ba3f32c855a8471832cf519d.setContent(html_c42bdf193dccfb00967d3cc4e2ed5feb);
#
#
#
#         marker_0fddd815e59c602cc1db21c054067870.bindPopup(popup_12f4de33ba3f32c855a8471832cf519d)
#         ;
#
#
#
#
#             var marker_fb105bdf21a31e046f9eb3f94b125cb8 = L.marker(
#                 [10.8896, -74.7808],
#                 {}
#             ).addTo(map_fca4ca4079c4f4f7b1bfeed088a6937c);
#
#
#         var popup_11fcd5d20b772c0a75c0ea637dd78661 = L.popup({&
# Menú de consulta de aeropuertos:
# 1. Mostrar información de un aeropuerto y Mostrar la información de los 10 aeropuertos cuyos caminos mínimos desde el vértice dado sean los más largos.
# 2. Mostrar el camino mínimo entre el primer y el segundo vértice sobre el mapa de la interfaz gráfica
# 3. Salir
# Seleccione una opción: 3
